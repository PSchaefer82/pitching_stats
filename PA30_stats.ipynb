# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from adjustText import adjust_text

# %%
# import csv file
file = "data/MLB_stats.csv"

df = mouse_metadata = pd.read_csv(file)

df = df.drop(columns=["year"])

df.head()
# Out:
#   last_name, first_name  player_id   pa  k_percent  bb_percent   woba  xwoba  \
# 0        Giolito, Lucas     608337  444       19.6         7.7  0.310  0.360
# 1       Walker, Taijuan     592836  392       16.6         7.1  0.316  0.323
# 2        Quintana, Jose     500779  419       16.5         8.6  0.311  0.351
# 3         Pivetta, Nick     601713  555       25.9         6.5  0.249  0.310
# 4       Williams, Gavin     668909  541       23.5        12.4  0.305  0.328
#
#    sweet_spot_percent  barrel_batted_rate  hard_hit_percent  avg_best_speed  \
# 0                40.2                10.0              41.7       80.225306
# 1                30.8                 6.4              38.6       78.264084
# 2                33.8                 9.6              43.1       77.766219
# 3                36.5                10.7              43.4       79.248133
# 4                33.0                 8.7              40.9       79.348378
#
#    avg_hyper_speed  z_swing_percent  oz_swing_percent  oz_contact_percent  \
# 0        94.921048             68.2              28.1                57.1
# 1        93.980719             63.7              26.6                66.3
# 2        94.618001             62.3              26.2                70.2
# 3        94.489158             64.7              28.4                59.8
# 4        94.432619             65.2              26.4                50.2
#
#    out_zone_percent  whiff_percent  swing_percent
# 0              48.6           22.5           48.7
# 1              49.8           18.4           45.2
# 2              52.8           17.7           43.2
# 3              46.5           25.0           47.8
# 4              51.4           27.8           45.2

# %%
# filter to pitchers who have only faced 30 of fewer batters
pitchers = df[(df['pa'] < 100)]
